# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
tf.__version__
# Out:
# '2.4.0'

# %% [markdown]
# Data Preprocessing

# %%
dataset = pd.read_csv('Concrete_Data.csv')
x = dataset.iloc[:,0 :-1].values
y = dataset.iloc[:, -1].values

# %%
dataset
# Out:
#       cement   slag  flyash  water  ...  coarseaggregate  fineaggregate  age  csMPa
# 0      540.0    0.0     0.0  162.0  ...           1040.0          676.0   28  79.99
# 1      540.0    0.0     0.0  162.0  ...           1055.0          676.0   28  61.89
# 2      332.5  142.5     0.0  228.0  ...            932.0          594.0  270  40.27
# 3      332.5  142.5     0.0  228.0  ...            932.0          594.0  365  41.05
# 4      198.6  132.4     0.0  192.0  ...            978.4          825.5  360  44.30
# ...      ...    ...     ...    ...  ...              ...            ...  ...    ...
# 1025   276.4  116.0    90.3  179.6  ...            870.1          768.3   28  44.28
# 1026   322.2    0.0   115.6  196.0  ...            817.9          813.4   28  31.18
# 1027   148.5  139.4   108.6  192.7  ...            892.4          780.0   28  23.70
# 1028   159.1  186.7     0.0  175.6  ...            989.6          788.9   28  32.77
# 1029   260.9  100.5    78.3  200.6  ...            864.5          761.5   28  32.40
#
# [1030 rows x 9 columns]

# %%
print(x)
# Out:
# [[ 540.     0.     0.  ... 1040.   676.    28. ]
#  [ 540.     0.     0.  ... 1055.   676.    28. ]
#  [ 332.5  142.5    0.  ...  932.   594.   270. ]
#  ...
#  [ 148.5  139.4  108.6 ...  892.4  780.    28. ]
#  [ 159.1  186.7    0.  ...  989.6  788.9   28. ]
#  [ 260.9  100.5   78.3 ...  864.5  761.5   28. ]]

# %%
print(y)
# Out:
# [79.99 61.89 40.27 ... 23.7  32.77 32.4 ]

# %% [markdown]
# Splitting dataset into training and test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train.shape
# Out:
# (824, 8)

# %%
x_test.shape
# Out:
# (206, 8)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# Buliding the ANN

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='relu'))

# %% [markdown]
# Training ANN

# %%
ann.compile(optimizer = 'adam', loss = 'mse', )

# %%
ann.fit(x_train, y_train, batch_size = 64, epochs = 100)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3145
# Epoch 2/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3242
# Epoch 3/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.2869
# Epoch 4/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.5042
# Epoch 5/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4068
# Epoch 6/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3131
# Epoch 7/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3845
# Epoch 8/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3763
# Epoch 9/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.4147
# Epoch 10/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3779
# Epoch 11/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3727
# Epoch 12/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3073
# Epoch 13/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3462
# Epoch 14/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3185
# Epoch 15/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.5465
# Epoch 16/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3012
# Epoch 17/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3090
# Epoch 18/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3321
# Epoch 19/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3075
# Epoch 20/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4015
# Epoch 21/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3871
# Epoch 22/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3581
# Epoch 23/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3224
# Epoch 24/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3233
# Epoch 25/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3032
# Epoch 26/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3375
# Epoch 27/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3959
# Epoch 28/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3114
# Epoch 29/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.2917
# Epoch 30/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3426
# Epoch 31/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3743
# Epoch 32/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3177
# Epoch 33/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3054
# Epoch 34/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.4301
# Epoch 35/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3288
# Epoch 36/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3824
# Epoch 37/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3061
# Epoch 38/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3589
# Epoch 39/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3288
# Epoch 40/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3712
# Epoch 41/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3123
# Epoch 42/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3239
# Epoch 43/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3084
# Epoch 44/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3315
# Epoch 45/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3929
# Epoch 46/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3837
# Epoch 47/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4207
# Epoch 48/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3902
# Epoch 49/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3312
# Epoch 50/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.7493
# Epoch 51/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3145
# Epoch 52/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3203
# Epoch 53/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3329
# Epoch 54/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.2802
# Epoch 55/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3073
# Epoch 56/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3155
# Epoch 57/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.6560
# Epoch 58/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3401
# Epoch 59/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4210
# Epoch 60/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.4070
# Epoch 61/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.2794
# Epoch 62/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.5676
# Epoch 63/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3349
# Epoch 64/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4083
# Epoch 65/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3124
# Epoch 66/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3126
# Epoch 67/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3593
# Epoch 68/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3110
# Epoch 69/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3161
# Epoch 70/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4243
# Epoch 71/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.4808
# Epoch 72/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3361
# Epoch 73/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.2864
# Epoch 74/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3394
# Epoch 75/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.4850
# Epoch 76/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.5509
# Epoch 77/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3386
# Epoch 78/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3336
# Epoch 79/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4279
# Epoch 80/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3366
# Epoch 81/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3279
# Epoch 82/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3632
# Epoch 83/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4282
# Epoch 84/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3384
# Epoch 85/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4456
# Epoch 86/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.3781
# Epoch 87/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3042
# Epoch 88/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3470
# Epoch 89/100
# 13/13 [==============================] - 0s 1ms/step - loss: 282.4182
# Epoch 90/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3274
# Epoch 91/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3305
# Epoch 92/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3034
# Epoch 93/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3542
# Epoch 94/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3208
# Epoch 95/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3279
# Epoch 96/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.4975
# Epoch 97/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3081
# Epoch 98/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3665
# Epoch 99/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3490
# Epoch 100/100
# 13/13 [==============================] - 0s 2ms/step - loss: 282.3117

# %%
example_set = x[6:7]
example_set
# Out:
# array([[380.,  95.,   0., 228.,   0., 932., 594., 365.]])

# %%
result = ann.predict(example_set)
print(result)
# Out:
# [[36.099342]]
